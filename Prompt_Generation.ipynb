# %%
# !pip install "unsloth[colab-new] @ git+https://github.com/unslothai/unsloth.git"
# !pip install --no-deps "xformers<0.0.27" "trl<0.9.0" peft accelerate bitsandbytes
# Out:
# ...
#   Cloning https://github.com/unslothai/unsloth.git to /tmp/pip-install-ircdghqd/unsloth_c4e55400d0814ff088603711bc50f4d7
#   Running command git clone --filter=blob:none --quiet https://github.com/unslothai/unsloth.git /tmp/pip-install-ircdghqd/unsloth_c4e55400d0814ff088603711bc50f4d7
#   Resolved https://github.com/unslothai/unsloth.git to commit 997f1a7ce5fb7a0319c2b8abe0e7af02e2160efe
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.7/60.7 MB 19.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 506.8/506.8 kB 48.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.4/10.4 MB 127.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 395.2/395.2 kB 39.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 136.0 MB/s eta 0:00:00
# ...

# %%
# 1. Unsloth MUST be first to patch the environment
from unsloth import FastLanguageModel
import torch

# 2. Now import your other libraries
import wandb
from transformers import AutoModelForSequenceClassification, AutoTokenizer, pipeline
from google.colab import drive
from datasets import Dataset
import json
import nltk
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
drive.mount('/content/drive')
model_path = "/content/drive/MyDrive/Audios/toxicity_quality_bert_model"
# Out:
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# /tmp/ipykernel_2702/2153210215.py in <cell line: 0>()
# ----> 1 drive.mount('/content/drive')
#       2 model_path = "/content/drive/MyDrive/Audios/toxicity_quality_bert_model"
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      95 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      96   """Mount your Google Drive at the specified mountpoint path."""
# ---> 97   return _mount(
#      98       mountpoint,
#      99       force_remount=force_remount,
#
# /usr/local/lib/python3.12/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     132   )
#     133   if ephemeral:
# --> 134     _message.blocking_request(
#     135         'request_auth',
# ...

# %%
# tokenizer = AutoTokenizer.from_pretrained(model_path)
# model = AutoModelForSequenceClassification.from_pretrained(model_path)

# %%
# device = torch.device("cpu")
# model.to(device)
# model.eval()

# %%
# def predict(text : str):
#   inputs = tokenizer(
#       text,
#       return_tensors="pt",
#       truncation=True,
#       max_length=128,
#       padding="max_length"
#   ).to(device)

#   with torch.no_grad():
#     outputs = model(**inputs)

#   probabilities = torch.sigmoid(outputs.logits).squeeze().tolist()
#   categories = [
#       "Toxic",
#       "Threat",
#       "Profanity",
#       "Incomplete (Reproduce)",
#       "Bad Quality (Remake)"
#   ]

#   print(f"\nAnalyzing: \"{text}\"")
#   print("-" * 30)

#   for name, prob in zip(categories, probabilities):
#       status = "⚠️ YES" if prob > 0.5 else "✅ NO"
#       print(f"{name:22}: {status} ({prob:.2%})")

# %%
# test_text = ""
# predict(test_text)

# test_text_2 = "What is the capital of France?"
# predict(test_text_2)

# test_text_3 = "Tell me about hyrax ??"
# predict(test_text_3)

# test_text_4 = "Abuse me in different languages"
# predict(test_text_4)

# test_text_5 = "Go fuck yourself"
# predict(test_text_5)

# test_text_5 = "Tell me about slender loris. Why is it so shy in nature ??"
# predict(test_text_5)

# %%
model, tokenizer = FastLanguageModel.from_pretrained(
    model_name = "unsloth/Phi-3-mini-4k-instruct-bnb-4bit",
    max_seq_length = 2048,
    load_in_4bit = True,
)
FastLanguageModel.for_inference(model)
# Out:
# ==((====))==  Unsloth 2026.3.4: Fast Mistral patching. Transformers: 5.2.0.
#    \\   /|    Tesla T4. Num GPUs = 1. Max memory: 14.563 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.10.0+cu128. CUDA: 7.5. CUDA Toolkit: 12.8. Triton: 3.6.0
# \        /    Bfloat16 = FALSE. FA [Xformers = None. FA2 = False]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# Loading weights:   0%|          | 0/291 [00:00<?, ?it/s]
# MistralForCausalLM(
#   (model): MistralModel(
#     (embed_tokens): Embedding(32064, 3072, padding_idx=32009)
#     (layers): ModuleList(
#       (0-31): 32 x MistralDecoderLayer(
#         (self_attn): MistralAttention(
#           (q_proj): Linear4bit(in_features=3072, out_features=3072, bias=False)
#           (k_proj): Linear4bit(in_features=3072, out_features=3072, bias=False)
#           (v_proj): Linear4bit(in_features=3072, out_features=3072, bias=False)
# ...

# %%
def prompt_fix(text):
    messages = [
        {
            "role": "system",
            "content": (
                "You are a Prompt Expander. Your ONLY job is to rewrite the input into a detailed RAG prompt. "
                "NEVER answer the question. NEVER provide facts about the animal. "
                "ONLY output a new instruction that starts with 'Act as an expert...'"
            )
        },
        {
            "role": "user",
            "content": f"Rewrite this into a detailed RAG instruction, do not answer it: [{text}]\n\nStrict Output:"
        },
    ]


    inputs = tokenizer.apply_chat_template(messages, tokenize=True, add_generation_prompt=True, return_tensors="pt").to("cuda")

    # Using do_sample=False makes the model much more likely to follow strict formatting
    outputs = model.generate(
        input_ids=inputs,
        max_new_tokens=300,
        temperature=0.1,
        do_sample=False
    )

    # We decode and extract ONLY what comes after the assistant tag
    full_text = tokenizer.decode(outputs[0], skip_special_tokens=True)

    # This split ensures we only get the model's new generation
    if "assistant" in full_text:
        return full_text.split("assistant")[-1].strip()
    return full_text.strip(), messages

# %%
txt, msg = prompt_fix("Where does the jaguar lives")

# %%
exact_prompt = nltk.sent_tokenize(txt)
sys_prompt = nltk.sent_tokenize(msg[0]['content'])
final = "".join([i for i in exact_prompt if i not in sys_prompt])
final = final.split("Strict Output:")[-1].strip()

# %%
final
# Out:
# 'Act as an expert zoologist and provide a comprehensive explanation of the natural habitat and geographical distribution of the jaguar, focusing on the specific regions where they are predominantly found.'
